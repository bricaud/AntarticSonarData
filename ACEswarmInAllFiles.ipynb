# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import scipy.signal

# %%
import ACE_box
import importlib
importlib.reload(ACE_box)
# Out:
# <module 'ACE_box' from '/home/benjamin/Documents/datascience/data jam days/scripts/ACE_box.py'>

# %% [markdown]
# ## Data import
# We import the csv file.
# We are interested in the  Ping_index , Ping_date , Ping_time , Latitude,  Longitude , and the sv* columns.
# Each sv* column corresponds to a depth.
# The value for each cell is the logarithm of the intensity of the echo.(ratio of intensity)

# %%
#data_path = '/home/benjamin/Documents/datascience/ACE/test/'
data_path = '/home/benjamin/Documents/datascience/ACE/'

# %% [markdown]
# ### Filtering

# %%
import glob
global_swarm_list = []
for filename in glob.iglob(data_path+'*.csv'):
    print('Loading data ...')
    print('%s' % filename)    
    info_df,echogram,depth_data = ACE_box.extract_data(filename)
    print('Filtering data...')
    denoised = ACE_box.filter_data(echogram)
    print('Finding krill swarms...')
    krillsignal,energy_fluctuation = ACE_box.krill_function(denoised,1)
    print('Energy fluctuation:',energy_fluctuation)
    swarm_echo_list = ACE_box.extract_krillchunks(krillsignal,denoised)
    print("Nb of swarms found: ",len(swarm_echo_list))
    print('Extracting swarm information...')
    swarm_list = ACE_box.info_from_swarm_list(swarm_echo_list,echogram,info_df,depth_data,filename)
    print('Done.')
    print('+++++++++++++')
    global_swarm_list += swarm_list
# Out:
# Loading data ...
# /home/benjamin/Documents/datascience/ACE/ACE_-D20170208-T013539.sv.csv
# ------------------------------
# Data matrix size: (2693, 9146)
# Start depth (in meters): 0.09278976
# Stop depth (in meters): 499.8584359
# Nb of pixels along depth axis: 2693
# Depth per pixel (in meters): 0.185579519547
# Echogram truncated to the first 100 meters (492 pixels).
# -----------------------------
# Filtering data...
# Number of noisy pixels:  5860
# Finding krill swarms...
# Energy fluctuation: 0.649745238123
# Nb of swarms found:  194
# Extracting swarm information...
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Done.
# +++++++++++++
# Loading data ...
# /home/benjamin/Documents/datascience/ACE/ACE_-D20170209-T051504.sv.csv
# ------------------------------
# Data matrix size: (2693, 9147)
# Start depth (in meters): 0.09278976
# Stop depth (in meters): 499.8584359
# Nb of pixels along depth axis: 2693
# Depth per pixel (in meters): 0.185579519547
# Echogram truncated to the first 100 meters (492 pixels).
# -----------------------------
# Filtering data...
# Number of noisy pixels:  45182
# Finding krill swarms...
# Energy fluctuation: 0.316091186543
# Nb of swarms found:  1356
# Extracting swarm information...
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Done.
# +++++++++++++
# Loading data ...
# /home/benjamin/Documents/datascience/ACE/ACE_-D20170209-T121539.sv.csv
# ------------------------------
# Data matrix size: (2693, 9145)
# Start depth (in meters): 0.09278976
# Stop depth (in meters): 499.8584359
# Nb of pixels along depth axis: 2693
# Depth per pixel (in meters): 0.185579519547
# Echogram truncated to the first 100 meters (492 pixels).
# -----------------------------
# Filtering data...
# Number of noisy pixels:  49205
# Finding krill swarms...
# Energy fluctuation: 0.308730863475
# Nb of swarms found:  1329
# Extracting swarm information...
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# ...
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Done.
# +++++++++++++
# Loading data ...
# /home/benjamin/Documents/datascience/ACE/ACE_-D20170207-T104031.sv.csv
# ------------------------------
# Data matrix size: (2693, 9163)
# Start depth (in meters): 0.09278976
# Stop depth (in meters): 499.8584359
# Nb of pixels along depth axis: 2693
# Depth per pixel (in meters): 0.185579519547
# Echogram truncated to the first 100 meters (492 pixels).
# -----------------------------
# Filtering data...
# Number of noisy pixels:  5333
# Finding krill swarms...
# Energy fluctuation: 0.716016389486
# Nb of swarms found:  58
# Extracting swarm information...
# Swarm with height = 0 !
# Done.
# +++++++++++++
# Loading data ...
# /home/benjamin/Documents/datascience/ACE/ACE_-D20170208-T153251.sv.csv
# ------------------------------
# Data matrix size: (2693, 9160)
# Start depth (in meters): 0.09278976
# Stop depth (in meters): 499.8584359
# Nb of pixels along depth axis: 2693
# Depth per pixel (in meters): 0.185579519547
# Echogram truncated to the first 100 meters (492 pixels).
# -----------------------------
# Filtering data...
# Number of noisy pixels:  7071
# Finding krill swarms...
# Energy fluctuation: 0.90528249225
# Nb of swarms found:  51
# Extracting swarm information...
# Done.
# +++++++++++++
# Loading data ...
# /home/benjamin/Documents/datascience/ACE/ACE_-D20170207-T210420.sv.csv
# ------------------------------
# Data matrix size: (2693, 3729)
# Start depth (in meters): 0.09278976
# Stop depth (in meters): 499.8584359
# Nb of pixels along depth axis: 2693
# Depth per pixel (in meters): 0.185579519547
# Echogram truncated to the first 100 meters (492 pixels).
# -----------------------------
# Filtering data...
# Number of noisy pixels:  2200
# Finding krill swarms...
# Energy fluctuation: 0.65737556104
# Nb of swarms found:  31
# Extracting swarm information...
# Swarm with height = 0 !
# Swarm with height = 0 !
# Swarm with height = 0 !
# Done.
# +++++++++++++

# %%
len(global_swarm_list)
# Out:
# 8101

# %%
# %matplotlib notebook
H,L = [],[]
for swarm in global_swarm_list:
    if swarm['length']>0 and swarm['height']>0 and swarm['depth']<80:
        H.append(swarm['height'])
        L.append(swarm['length'])
#plt.scatter(H,L)
plt.hist2d(H, L, bins=(100, 30), cmap=plt.cm.jet)
plt.xlabel('Height (m)')
plt.ylabel('Length (m)')
plt.title('Distribution of swarm sizes')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Distribution of swarm sizes')

# %%
D,L = [],[]
for swarm in global_swarm_list:
    if swarm['length']>0 and swarm['height']>0 and swarm['depth']<80:
        D.append(swarm['depth'])
        L.append(swarm['length'])
#plt.scatter(D,L)
plt.hist2d(D, L, bins=(100, 30), cmap=plt.cm.jet)
plt.xlabel('Depth')
plt.ylabel('Length')
plt.title('Swarm length w.r.t. depth')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Swarm length w.r.t. depth')

# %%
D,H = [],[]
for swarm in global_swarm_list:
    if swarm['length']>0 and swarm['height']>0 and swarm['depth']<80:
        D.append(swarm['depth'])
        H.append(swarm['height'])
#plt.scatter(D,H)
plt.hist2d(D, H, bins=(100, 30), cmap=plt.cm.jet)
plt.xlabel('Depth (m)')
plt.ylabel('Height (m)')
plt.title('Swarm height w.r.t. depth')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Swarm height w.r.t. depth')

# %%
D,B = [],[]
for swarm in global_swarm_list:
    if swarm['biomass_per_pixel']!=0: #filter bad swarms
        if swarm['length']>0:
            D.append(swarm['depth'])
            B.append(10*np.log10(swarm['biomass_per_pixel']))


#plt.scatter(D,B)
plt.hist2d(D, B, bins=(100, 30), cmap=plt.cm.jet)
plt.xlabel('Depth (m)')
plt.ylabel('Biomass index (Mean sonar intensity per pixel)')
plt.title('Swarm bio mass w.r.t. depth')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Swarm bio mass w.r.t. depth')

# %%
D,B = [],[]
for swarm in global_swarm_list:
    if swarm['biomass_per_pixel']!=0: #filter bad swarms
        if swarm['length']>0:
            D.append(swarm['length'])
            B.append(10*np.log10(swarm['biomass_per_pixel']))
#plt.scatter(D,B)
plt.hist2d(D, B, bins=(100, 30), cmap=plt.cm.jet)
plt.xlabel('Length (m)')
plt.ylabel('Biomass index (Mean sonar intensity per pixel)')
plt.title('Swarm bio mass w.r.t. length')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Swarm bio mass w.r.t. length')

# %%
D,B = [],[]
for swarm in global_swarm_list:
    if swarm['biomass_per_pixel']!=0: #filter bad swarms
        if swarm['length']>0:
            D.append(swarm['height'])
            B.append(10*np.log10(swarm['biomass_per_pixel']))
#plt.scatter(D,B)
plt.hist2d(D, B, bins=(100, 30), cmap=plt.cm.jet)
plt.xlabel('Height (m)')
plt.ylabel('Biomass index (Mean sonar intensity per pixel)')
plt.title('Swarm bio mass w.r.t. height')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Swarm bio mass w.r.t. height')

# %%
import json
with open('krill_data.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(global_krill_list, ensure_ascii=False))

# %%
def krill_depth(array):
    # Compute the depth of the krill swarm
    depth_function = np.sum(array,1)
